# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
CodeAplha = pd.read_excel("/content/drive/MyDrive/employee_data_10000.xlsx")
CodeAplha.head()
# Out:
#   EmployeeID               Name  Age  Gender      Department     Position  \
# 0   EMP00001  Danielle Campbell   49  Female  Data Analytics  Coordinator
# 1   EMP00002     William Bailey   44    Male      Operations   Specialist
# 2   EMP00003     Maria Robinson   33  Female         Finance    Executive
# 3   EMP00004        Thomas Rios   49    Male              HR  Coordinator
# 4   EMP00005        Mark Powers   28    Male              HR      Analyst
#
#    Salary  ExperienceYears           City JoiningDate
# 0   46420               24    Ashleyhaven  2017-04-18
# 1   37476               23      Ellisbury  2021-07-18
# 2  103104               10    Leonardberg  2026-02-21
# 3  141009               30  Griffithmouth  2024-03-09
# 4   45964               13   West Sabrina  2018-05-12

# %%
CodeAplha.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   EmployeeID       10000 non-null  object
#  1   Name             10000 non-null  object
#  2   Age              10000 non-null  int64
#  3   Gender           10000 non-null  object
#  4   Department       10000 non-null  object
#  5   Position         10000 non-null  object
#  6   Salary           10000 non-null  int64
#  7   ExperienceYears  10000 non-null  int64
#  8   City             10000 non-null  object
#  9   JoiningDate      10000 non-null  object
# dtypes: int64(3), object(7)
# memory usage: 781.4+ KB

# %%
CodeAplha.describe()
# Out:
#                 Age         Salary  ExperienceYears
# count  10000.000000   10000.000000     10000.000000
# mean      40.468400   87798.877900        17.469200
# std       11.652158   36118.448774        10.422059
# min       21.000000   25008.000000         0.000000
# 25%       30.000000   57224.250000         8.000000
# 50%       40.000000   87662.000000        18.000000
# 75%       51.000000  118888.250000        26.000000
# max       60.000000  149999.000000        35.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(CodeAplha.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
numeric_col = CodeAplha.select_dtypes(include='number').columns[0]

plt.figure(figsize=(8,5))
sns.histplot(CodeAplha[numeric_col], kde=True)
plt.title(f"Distribution of {numeric_col}")
plt.show()

# %%
import plotly.express as px

fig = px.scatter(
    CodeAplha,
    x='ExperienceYears',
    y='Salary',
    color='Department',
    size='Salary',
    hover_name='Name',
    title='Experience vs Salary by Department'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    "Review": [
        "This product is amazing",
        "Very bad quality",
        "I love this phone",
        "Worst purchase ever",
        "Average product",
        "Excellent battery life",
        "Not worth the money",
        "Highly recommended",
        "Terrible experience",
        "Good value for money"
    ]
}

df = pd.DataFrame(data)
df.head()
# Out:
#                     Review
# 0  This product is amazing
# 1         Very bad quality
# 2        I love this phone
# 3      Worst purchase ever
# 4          Average product

# %%
def get_sentiment(text):
    polarity = TextBlob(text).sentiment.polarity

    if polarity > 0:
        return "Positive"
    elif polarity < 0:
        return "Negative"
    else:
        return "Neutral"

# %%
df["Sentiment"] = df["Review"].apply(get_sentiment)

df
# Out:
#                     Review Sentiment
# 0  This product is amazing  Positive
# 1         Very bad quality  Negative
# 2        I love this phone  Positive
# 3      Worst purchase ever  Negative
# 4          Average product  Negative
# 5   Excellent battery life  Positive
# 6      Not worth the money  Negative
# 7       Highly recommended  Positive
# 8      Terrible experience  Negative
# 9     Good value for money  Positive

# %%
sentiment_counts = df["Sentiment"].value_counts()

print(sentiment_counts)
# Out:
# Sentiment
# Positive    5
# Negative    5
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))

sns.countplot(
    x="Sentiment",
    data=df,
    order=["Positive","Neutral","Negative"]
)

plt.title("Sentiment Analysis of Reviews")
plt.show()

# %%
df["Sentiment"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%",
    figsize=(6,6)
)

plt.ylabel("")
plt.title("Sentiment Distribution")
plt.show()

# %%
df.to_csv("sentiment_results.csv", index=False)

print("File Saved Successfully")
# Out:
# File Saved Successfully
